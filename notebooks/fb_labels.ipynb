# %%
import numpy as np
import pandas as pd
pd.set_option("max_colwidth", 200)

import json
import re

import spacy
from spacy.language import Language
from spacy.lang.en.stop_words import STOP_WORDS

from tqdm.notebook import tqdm

from gen_funcs_fb import *
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing data and applying labels.

# %% [markdown]
# Preparing FB data to make predictions on.

# %%
fb_data = pd.read_csv('/Users/christineegan/spacy_workspace/data/facebook/en-US.csv')
print('# of observations:', len(fb_data))
# Out:
# # of observations: 222186

# %% [markdown]
# ### Identifying Most Common Payers

# %%
# figuring out if the person who is paying for the ad is con or lib
payer_vals = pd.DataFrame(fb_data['paid_for_by'].value_counts())

# limiting the list to only those payers who places 100 or more ads 
payer_vals = payer_vals[payer_vals['paid_for_by'] >= 100]
payers = list(payer_vals.index)
# payers = [payer.lower() for payer in payers]
# payers = [payer.lower() for payer in payers]
payers = list(set(payers)) # dropping any exact duplicates
print(len(payers), 'different payers with more than 100 ads.\n')
# pprint(payers)
# Out:
# 264 different payers with more than 100 ads.

# %%
# fb_data['in_payers'] = fb_data['paid_for_by'].apply(lambda x: 1 if x in payers else 0)
# data = fb_data.loc[fb_data['in_payers'] == 1]
# print(len(data), 'different ads from payers with more than 100 ads.\n')

# %%
fb_data['paid_for_by'] = fb_data['paid_for_by'].fillna('Missing')
fb_payers = list(fb_data['paid_for_by'])
fb_payers = [payer.lower() for payer in fb_payers if payer.lower() in payers]
fb_data['in_payers'] = fb_data['paid_for_by'].apply(lambda x: 1 if x.lower() in fb_payers else 0)

# %%
data = fb_data.loc[fb_data['in_payers'] == 1]
print(len(data), 'different ad from payers with more than 100 ads.\n')
# Out:
# 266 different ad from payers with more than 100 ads.

# %% [markdown]
# ### Creating a Payers DataFrame

# %%
# preprocessing

# I decided not to clean these because it messes up the NER
payer_df = pd.DataFrame(payers, columns=['payers'])

nlp = spacy.load('en_core_web_md')
docs = [nlp(doc) for doc in payer_df['payers']] # a list of nlp.docs
lemmatized_docs = [[n.lemma_ for n in doc 
                    if n.is_stop == False  # removing stops
                    and n.is_punct == False # ...punctuation
                    and n.is_digit == False # ...digits
                    and len(str(n)) >= 3]  # ...less than 3 letters
                   for doc in docs]  # list of lemmatized nlp docs
nes = [[ent.text for ent in doc.ents] for doc in docs]
ne_labels = [[ent.label_ for ent in doc.ents] for doc in docs]

payer_df['docs'] = docs
payer_df['lemmatized_docs'] = lemmatized_docs
payer_df['named_ents'] = nes
payer_df['ne_labels'] = ne_labels

# %%
docs # sanity check
# Out:
# [World Wildlife Fund,
#  Everytown for Gun Safety Action Fund,
#  AIDS United, Inc.,
#  Covenant House International,
#  Mike Gravel 2020,
#  Cory 2020,
#  END CITIZENS UNITED,
#  HICKENLOOPER FOR COLORADO,
#  the Republican National Committee,
#  Feeding America,
#  Shareblue Media,
#  Montanans for Tester,
#  Bee Site,
#  Oxfam America,
#  DONALD J. TRUMP FOR PRESIDENT, INC.,
#  Greenpeace USA,
#  National Domestic Workers Alliance,
#  Beto for Texas,
#  Independence USA. Not authorized by any candidate or candidate's committee.,
#  UNICEF USA,
#  Ben & Jerry's,
#  America First Policies,
#  Bullock for President,
#  DNC SERVICES CORP./DEM. NAT'L COMMITTEE,
#  MoveOn.org Civic Action.,
#  the Trump Make America Great Again Committee,
#  BOOKER FOR KENTUCKY,
#  SIERRA CLUB,
#  Indivisible Action,
#  UNITED STATES ASSOCIATION FOR UNHCR,
#  PredictIt is a political prediction market, a stock market for politics. A project of Victoria University of Wellington, P…,
#  314 ACTION FUND,
#  Zephyr for NY,
#  Working Families Party,
#  Reason To Believe PAC,
#  Stop Republicans,
#  Women's March,
#  Alexandria Ocasio-Cortez for Congress,
#  cleancult,
#  PragerU,
#  Earthjustice,
#  NARAL Pro-Choice America,
#  Care2,
#  JON OSSOFF FOR SENATE,
#  Dissent Pins,
#  Reproaction,
#  Tom Steyer 2020,
#  Catholic Relief Services,
#  SCHIFF FOR CONGRESS,
#  No on Proposition 8: Stop the Dangerous Dialysis Proposition,
#  Jaime Harrison for U.S. Senate,
#  The Beauty of Life,
#  HUMAN RIGHTS CAMPAIGN, INC.,
#  Cordray/Sutton Committee,
#  Defending Democracy Together,
#  American Medical Association,
#  Priorities USA Action and SMP. (302) 469-3772. (202) 871-9255. Not authorized by any candidate or candidate's committee.,
#  SOLAR ENERGY TODAY,
#  Progressive Turnout Project,
#  Kialo,
#  Planned Parenthood Federation of America,
#  Bird + Stone ,
#  ExxonMobil,
#  FCTRY,
#  Sandy Hook Promise,
#  MOVEON.ORG CIVIC ACTION,
#  EMILY's List,
#  BIDEN VICTORY FUND,
#  The Wilderness Society,
#  Fair Fight Action,
#  Center for Biological Diversity,
#  The Humane Society of the United States,
#  O’Connor for Congress,
#  the NRCC and not authorized by any candidate or candidate's committee.,
#  Everytown for Gun Safety Action Fund Inc,
#  Michigan Leadership Committee. Not authorized by any candidate.,
#  Ban Assault Weapons NOW,
#  No Kid Hungry,
#  the Democratic National Committee,
#  Gillibrand for Senate,
#  International Rescue Committee,
#  PragerU ,
#  MARK KELLY FOR SENATE,
#  Beto for America,
#  Planned Parenthood Action Fund,
#  Southern Poverty Law Center,
#  Mike Bloomberg 2020 Inc,
#  Beachside Media, Inc.,
#  IVN News,
#  Heifer International,
#  SARA GIDEON FOR MAINE,
#  USA for UNHCR,
#  The Nature Conservancy,
#  National Audubon Society,
#  Sinema for Arizona,
#  Stand Up America,
#  INDIVISIBLE ACTION,
#  Ditch Fund and not authorized by any candidate or candidate's committee,
#  NRDC Action Fund,
#  Civiqs,
#  Democratic Governors Association,
#  Amnesty International USA,
#  Alliance Defending Freedom,
#  BERNIE 2020,
#  U.S. Census Bureau,
#  Elizabeth for MA,
#  AARP,
#  PETE FOR AMERICA, INC.,
#  Covenant House,
#  Alliance for a Better Minnesota Action Fund,
#  JUSTICE DEMOCRATS PAC,
#  The Intercept,
#  Anti-Defamation League,
#  National Park Foundation,
#  HOUSE MAJORITY PAC, (202) 849-6052, AND PRIORITIES USA ACTION, (302) 469-3772. NOT AUTHORIZED BY ANY CANDIDATE OR CANDIDAT…,
#  The Wall Street Journal,
#  World Food Program USA,
#  Bernie 2020.,
#  Committee to Elect Richard Ojeda,
#  The Christian Science Monitor, an international news organization,
#  The Lincoln Project,
#  Patagonia ,
#  Donald J. Trump for President, Inc.,
#  Dean Phillips for Congress,
#  TYT Network,
#  the National Network of Abortion Funds,
#  Clean Air Clean Energy Washington 4347 Roosevelt Way NE Seattle, WA 98105,
#  BIDEN FOR PRESIDENT,
#  National Education Association,
#  Hickenlooper 2020,
#  Planned Parenthood Action Fund.,
#  Kamala Harris For The People,
#  INSLEE FOR AMERICA,
#  Indivisible Project,
#  MOVEON.ORG POLITICAL ACTION,
#  MARIANNE WILLIAMSON FOR PRESIDENT,
#  Americans for Prosperity,
#  Penzeys,
#  Define American,
#  Daily Wire,
#  314 Action Fund,
#  Swing Left. Not authorized by any candidate or candidate's committee.,
#  Lupe Valdez for Governor,
#  Environmental Defense Fund,
#  GREENPEACE, INC.,
#  Civic Action,
#  The Climate Reality Project,
#  PROGRESSIVE TURNOUT PROJECT,
#  Keep and Bear,
#  UNION OF CONCERNED SCIENTISTS, INC.,
#  the Democratic Governors Association.,
#  McCaskill for Missouri,
#  U.S. Chamber of Commerce,
#  Yale Program on Climate Change Communication,
#  Stacey Abrams for Governor,
#  Our Colorado Way of Life,
#  The Motley Fool,
#  Giffords.,
#  Secure Financial Advisory Group,
#  Chesapeake Bay Foundation,
#  McCready for Congress,
#  Randy Bryce for Congress,
#  Justice Democrats, not authorized by any candidate or candidate's committee.,
#  Mercy Corps,
#  Sara Gideon for Maine,
#  MoveOn.org Political Action, pol.moveon.org, not authorized by any candidate or candidate's committee.,
#  Chad Benson,
#  the Progressive Change Campaign Committee PAC and not authorized by any candidate or candidate's committee. Contributions …,
#  Better Place Forests,
#  JB for Governor,
#  Cory Booker for Senate ,
#  Defenders of Wildlife,
#  WARREN FOR PRESIDENT, INC.,
#  National Trust for Historic Preservation,
#  American Civil Liberties Union,
#  Ammar Campa-Najjar for Congress.,
#  TOM STEYER 2020,
#  the Voter Participation Center,
#  AMY MCGRATH FOR SENATE, INC.,
#  Reform Austin, Inc. ,
#  MoveOn.org Political Action, not authorized by any candidate or candidate’s committee.,
#  Tony for Wisconsin. Connie Hutchison, Treasurer.,
#  Sierra Club,
#  DCCC,
#  TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE,
#  NATIONAL AUDUBON SOCIETY, INC.,
#  JAIME HARRISON FOR US SENATE,
#  DSCC,
#  Dr. Kim Schrier for Congress,
#  League of Conservation Voters,
#  Bill Nelson for U.S. Senate,
#  Adam Schiff for Congress,
#  Bennet for America,
#  Concerned Veterans for America,
#  Oceana,
#  The Washington Post,
#  OZY Media,
#  DITCH FUND,
#  the National Democratic Training Committee,
#  Jeff Merkley for Oregon,
#  Andrew Gillum, Democrat, for Governor,
#  the DSCC,
#  Andrew Yang,
#  the Florida Democratic Party. Not authorized by any candidate or candidate's committee.,
#  DOUG JONES FOR SENATE COMMITTEE,
#  BallotReady,
#  Hoover Institution,
#  Union of Concerned Scientists,
#  CRTV,
#  Joe Kennedy for Congress.,
#  Everytown for Gun Safety Action Fund. Not authorized by any candidate or candidate’s committee.,
#  Phone2Action,
#  Biden for President,
#  and Authorized by  Andrew Janz for Congress.,
#  CARE,
#  NRDC,
#  Julián for the Future,
#  Be a Hero PAC. Not authorized by any candidate or candidate’s committee.,
#  Judicial Watch,
#  MoveOn.org Political Action, not authorized by any candidate or candidate's committee.,
#  End Citizens United,
#  Natural Resources Defense Council,
#  Andy Kim for Congress,
#  Ocean Conservancy,
#  WILDERNESS SOCIETY, THE,
#  FWD.us,
#  Human Rights Watch,
#  Amy for America,
#  Doctors Without Borders/Médecins Sans Frontières (MSF),
#  Need to Impeach,
#  VoteVets Action Fund,
#  News For Democracy,
#  LIFE Outreach International ,
#  NANCY PELOSI FOR CONGRESS,
#  PAC TO THE FUTURE,
#  Montanans for Bullock,
#  Cathy for Congress,
#  Pete for America,
#  the ACLU,
#  MJ for Texas,
#  Mark Kelly for Senate,
#  Friends of the Earth,
#  Andrew Cuomo for Governor,
#  Priorities USA Action. 202-455-8428. Not authorized by any candidate or candidate's committee.,
#  Sharice for Congress,
#  Kamala Harris for Senate,
#  CREDO Mobile,
#  CAL FOR NC,
#  Ohio Safe & Healthy Communities Campaign,
#  Heidi for North Dakota,
#  the Democratic National Committee, 1.877.336.7200. Not authorized by any candidate or candidate’s committee.,
#  Color Of Change,
#  Mikie Sherrill for Congress,
#  Seth Moulton for America,
#  Amy McGrath for Senate,
#  National Geographic Society,
#  HIAS,
#  TULSI NOW,
#  Winning For Women, Inc.,
#  Voters Not Politicians | PO Box 8362 Grand Rapids, MI 49518,
#  Gillibrand 2020,
#  Human Rights Campaign,
#  ALEXANDRIA OCASIO-CORTEZ FOR CONGRESS,
#  Warren for President]

# %%
payer_df['original'] = payer_df['payers']
payer_df['payers'] = payer_df['payers'].str.lower()
payer_df = payer_df.drop_duplicates(subset=['payers'])
payer_df = payer_df.sort_values(by='named_ents').reset_index().drop('index', axis=1)
# display(payer_df)

# there seem to be a lot of empty ones
payer_df['label'] = payer_df['named_ents'].apply(lambda x: x[0] if len(x) != 0 else 'missing')
# display(payer_df)

# %%
payer_df = payer_df.drop_duplicates(subset=['payers'])
unknown_payers = payer_df.loc[payer_df['label'] == 'missing']
known_payers = payer_df.loc[payer_df['label'] != 'missing']
print('# of unknown payers:', len(unknown_payers)) # i'll call these 'unknown payers' and segment them to work with them.
print('# of known payers:', len(known_payers))
# Out:
# # of unknown payers: 66
# # of known payers: 187

# %% [markdown]
# ### Known payers

# %%
display(known_payers)
# Out:
#                                                                                                                           payers  \
# 66                                                                                                                   bernie 2020
# 67                                                                                                             hickenlooper 2020
# 68                                                                                                                     cory 2020
# 69                                                                                                               gillibrand 2020
# 70                                                                                                               314 action fund
# ..                                                                                                                           ...
# 248                                                                                   the national democratic training committee
# 249                                                                                       the national network of abortion funds
# 250  the progressive change campaign committee pac and not authorized by any candidate or candidate's committee. contributions …
# 251                                                                                            the republican national committee
# 252                                                                                               the voter participation center
#
#                                                                                                                                                   docs  \
# 66                                                                                                                                      (BERNIE, 2020)
# 67                                                                                                                                (Hickenlooper, 2020)
# 68                                                                                                                                        (Cory, 2020)
# 69                                                                                                                                  (Gillibrand, 2020)
# 70                                                                                                                                 (314, ACTION, FUND)
# ..                                                                                                                                                 ...
# 248                                                                                                   (the, National, Democratic, Training, Committee)
# 249                                                                                                      (the, National, Network, of, Abortion, Funds)
# 250  (the, Progressive, Change, Campaign, Committee, PAC, and, not, authorized, by, any, candidate, or, candidate, 's, committee, ., Contributions, …)
# 251                                                                                                             (the, Republican, National, Committee)
# 252                                                                                                                (the, Voter, Participation, Center)
#
#                                                                                                lemmatized_docs  \
# 66                                                                                                    [BERNIE]
# 67                                                                                              [Hickenlooper]
# 68                                                                                                      [Cory]
# 69                                                                                                [Gillibrand]
# 70                                                                                              [action, FUND]
# ..                                                                                                         ...
# 248                                                                [National, Democratic, Training, Committee]
# 249                                                                       [National, Network, Abortion, Funds]
# 250  [Progressive, Change, Campaign, Committee, PAC, authorize, candidate, candidate, committee, contribution]
# 251                                                                          [Republican, National, Committee]
# 252                                                                             [Voter, Participation, Center]
#
#                                        named_ents   ne_labels  \
# 66                                         [2020]      [DATE]
# 67                                         [2020]      [DATE]
# 68                                         [2020]      [DATE]
# 69                                         [2020]      [DATE]
# 70                                          [314]  [CARDINAL]
# ..                                            ...         ...
# 248  [the National Democratic Training Committee]       [ORG]
# 249      [the National Network of Abortion Funds]       [ORG]
# 250   [the Progressive Change Campaign Committee]       [ORG]
# 251           [the Republican National Committee]       [ORG]
# 252              [the Voter Participation Center]       [ORG]
#
#                                                                                                                         original  \
# 66                                                                                                                   BERNIE 2020
# 67                                                                                                             Hickenlooper 2020
# 68                                                                                                                     Cory 2020
# 69                                                                                                               Gillibrand 2020
# 70                                                                                                               314 ACTION FUND
# ..                                                                                                                           ...
# 248                                                                                   the National Democratic Training Committee
# 249                                                                                       the National Network of Abortion Funds
# 250  the Progressive Change Campaign Committee PAC and not authorized by any candidate or candidate's committee. Contributions …
# 251                                                                                            the Republican National Committee
# 252                                                                                               the Voter Participation Center
#
#                                           label
# 66                                         2020
# 67                                         2020
# 68                                         2020
# 69                                         2020
# 70                                          314
# ..                                          ...
# 248  the National Democratic Training Committee
# 249      the National Network of Abortion Funds
# 250   the Progressive Change Campaign Committee
# 251           the Republican National Committee
# 252              the Voter Participation Center
#
# [187 rows x 7 columns]

# %%
# some are wrong, so we should deal with those
# 2020
known_payers['label'] = known_payers['label'].apply(lambda x: x.lower())
known_payers['label'] = known_payers['label'].str.replace(r'(2020.*$)', 'missing', regex=True)

# %%
known_payers['label'] = known_payers['label'].str.replace(r'(^.*democrat.*$)', 'lib', regex=True)
known_payers['label'] = known_payers['label'].str.replace(r'(^.*republican.*$)', 'con', regex=True)
known_payers['label'] = known_payers['label'].str.replace(r'(^.*progressive.*$)', 'lib', regex=True)

# %%
known_payers
# Out:
#                                                                                                                           payers  \
# 66                                                                                                                   bernie 2020
# 67                                                                                                             hickenlooper 2020
# 68                                                                                                                     cory 2020
# 69                                                                                                               gillibrand 2020
# 70                                                                                                               314 action fund
# ..                                                                                                                           ...
# 248                                                                                   the national democratic training committee
# 249                                                                                       the national network of abortion funds
# 250  the progressive change campaign committee pac and not authorized by any candidate or candidate's committee. contributions …
# 251                                                                                            the republican national committee
# 252                                                                                               the voter participation center
#
#                                                                                                                                                   docs  \
# 66                                                                                                                                      (BERNIE, 2020)
# 67                                                                                                                                (Hickenlooper, 2020)
# 68                                                                                                                                        (Cory, 2020)
# 69                                                                                                                                  (Gillibrand, 2020)
# 70                                                                                                                                 (314, ACTION, FUND)
# ..                                                                                                                                                 ...
# 248                                                                                                   (the, National, Democratic, Training, Committee)
# 249                                                                                                      (the, National, Network, of, Abortion, Funds)
# 250  (the, Progressive, Change, Campaign, Committee, PAC, and, not, authorized, by, any, candidate, or, candidate, 's, committee, ., Contributions, …)
# 251                                                                                                             (the, Republican, National, Committee)
# 252                                                                                                                (the, Voter, Participation, Center)
#
#                                                                                                lemmatized_docs  \
# 66                                                                                                    [BERNIE]
# 67                                                                                              [Hickenlooper]
# 68                                                                                                      [Cory]
# 69                                                                                                [Gillibrand]
# 70                                                                                              [action, FUND]
# ..                                                                                                         ...
# 248                                                                [National, Democratic, Training, Committee]
# 249                                                                       [National, Network, Abortion, Funds]
# 250  [Progressive, Change, Campaign, Committee, PAC, authorize, candidate, candidate, committee, contribution]
# 251                                                                          [Republican, National, Committee]
# 252                                                                             [Voter, Participation, Center]
#
#                                        named_ents   ne_labels  \
# 66                                         [2020]      [DATE]
# 67                                         [2020]      [DATE]
# 68                                         [2020]      [DATE]
# 69                                         [2020]      [DATE]
# 70                                          [314]  [CARDINAL]
# ..                                            ...         ...
# 248  [the National Democratic Training Committee]       [ORG]
# 249      [the National Network of Abortion Funds]       [ORG]
# 250   [the Progressive Change Campaign Committee]       [ORG]
# 251           [the Republican National Committee]       [ORG]
# 252              [the Voter Participation Center]       [ORG]
#
#                                                                                                                         original  \
# 66                                                                                                                   BERNIE 2020
# 67                                                                                                             Hickenlooper 2020
# 68                                                                                                                     Cory 2020
# 69                                                                                                               Gillibrand 2020
# 70                                                                                                               314 ACTION FUND
# ..                                                                                                                           ...
# 248                                                                                   the National Democratic Training Committee
# 249                                                                                       the National Network of Abortion Funds
# 250  the Progressive Change Campaign Committee PAC and not authorized by any candidate or candidate's committee. Contributions …
# 251                                                                                            the Republican National Committee
# 252                                                                                               the Voter Participation Center
#
#                                       label
# 66                                  missing
# 67                                  missing
# 68                                  missing
# 69                                  missing
# 70                                      314
# ..                                      ...
# 248                                     lib
# 249  the national network of abortion funds
# 250                                     lib
# 251                                     con
# 252          the voter participation center
#
# [187 rows x 7 columns]

# %%
# if the word 'for' appears in the payers info, it is likely a candidate, so we can check for candidates
# and their affliations by checking out payers that contain 'for'
candidates_for = known_payers[known_payers['payers'].str.contains('for')]

display(candidates_for)
# Out:
#                                                                                                                           payers  \
# 73                                                                                                  amy mcgrath for senate, inc.
# 74                                                                                                      adam schiff for congress
# 75                                                                                         alexandria ocasio-cortez for congress
# 76                                                                                                               amy for america
# 81                                                                                                      americans for prosperity
# ..                                                                                                                           ...
# 235  predictit is a political prediction market, a stock market for politics. a project of victoria university of wellington, p…
# 236                                                                                                   warren for president, inc.
# 237                                                                                                         warren for president
# 238                                                                                                      winning for women, inc.
# 243                                                                                                                zephyr for ny
#
#                                                                                                                                                         docs  \
# 73                                                                                                                    (AMY, MCGRATH, FOR, SENATE, ,, INC, .)
# 74                                                                                                                             (Adam, Schiff, for, Congress)
# 75                                                                                                            (Alexandria, Ocasio, -, Cortez, for, Congress)
# 76                                                                                                                                       (Amy, for, America)
# 81                                                                                                                              (Americans, for, Prosperity)
# ..                                                                                                                                                       ...
# 235  (PredictIt, is, a, political, prediction, market, ,, a, stock, market, for, politics, ., A, project, of, Victoria, University, of, Wellington, ,, P, …)
# 236                                                                                                                      (WARREN, FOR, PRESIDENT, ,, INC, .)
# 237                                                                                                                                 (Warren, for, President)
# 238                                                                                                                           (Winning, For, Women, ,, Inc.)
# 243                                                                                                                                        (Zephyr, for, NY)
#
#                                                                                                    lemmatized_docs  \
# 73                                                                                     [AMY, MCGRATH, SENATE, INC]
# 74                                                                                        [Adam, Schiff, Congress]
# 75                                                                          [Alexandria, Ocasio, Cortez, Congress]
# 76                                                                                                  [Amy, America]
# 81                                                                                         [Americans, prosperity]
# ..                                                                                                             ...
# 235  [PredictIt, political, prediction, market, stock, market, politic, project, Victoria, University, Wellington]
# 236                                                                                       [WARREN, PRESIDENT, INC]
# 237                                                                                            [Warren, President]
# 238                                                                                             [win, Women, Inc.]
# 243                                                                                                       [Zephyr]
#
#                                named_ents           ne_labels  \
# 73             [AMY MCGRATH, SENATE, INC]  [PERSON, ORG, ORG]
# 74                [Adam Schiff, Congress]       [PERSON, ORG]
# 75   [Alexandria Ocasio-Cortez, Congress]       [PERSON, ORG]
# 76                              [America]               [GPE]
# 81                            [Americans]              [NORP]
# ..                                    ...                 ...
# 235   [Victoria University of Wellington]               [ORG]
# 236                         [WARREN, INC]          [ORG, ORG]
# 237                              [Warren]               [ORG]
# 238             [Winning For Women, Inc.]               [ORG]
# 243                          [Zephyr, NY]          [ORG, GPE]
#
#                                                                                                                         original  \
# 73                                                                                                  AMY MCGRATH FOR SENATE, INC.
# 74                                                                                                      Adam Schiff for Congress
# 75                                                                                         Alexandria Ocasio-Cortez for Congress
# 76                                                                                                               Amy for America
# 81                                                                                                      Americans for Prosperity
# ..                                                                                                                           ...
# 235  PredictIt is a political prediction market, a stock market for politics. A project of Victoria University of Wellington, P…
# 236                                                                                                   WARREN FOR PRESIDENT, INC.
# 237                                                                                                         Warren for President
# 238                                                                                                      Winning For Women, Inc.
# 243                                                                                                                Zephyr for NY
#
#                                  label
# 73                         amy mcgrath
# 74                         adam schiff
# 75            alexandria ocasio-cortez
# 76                             america
# 81                           americans
# ..                                 ...
# 235  victoria university of wellington
# 236                             warren
# 237                             warren
# 238            winning for women, inc.
# 243                             zephyr
#
# [75 rows x 7 columns]

# %%
# from that i extracted some known libs and cons
libs = ['elizabeth', 'nancy pelosi', 'hickenlooper', 'ammar campa-najjar', 
        'inslee for america', 'jaime harrison', 'adam schiff', 'mark kelly',
        'andrew cuomo', 'sinema', 'bill nelson', 'marianne williamson', 
        'dean phillips', 'jon ossoff', 'giffords', 'mikie sherrill', 'warren',
        'stacey abrams', 'gillibrand 2020', 'jeff merkley', 'pete for america',
        'hickenlooper 2020', 'seth moulton', 'biden', 'mike bloomberg 2020 inc',
        'andy kim', 'sara gideon', 'doug jones', 'bernie 2020', 'jb', 'kamala harris',
        'zephyr', 'cory booker', 'alexandria ocasio-cortez', 'beto', 'bernie 2020.',
        'randy bryce', 'amy mcgrath', 'sharice', 'lupe valdez', 'mccaskill', 'gillibrand',
        'mike gravel 2020', 'cory 2020', 'andrew gillum', 'joe kennedy', 'kim schrier',
        'tom steyer 2020', 'andrew janz']

cons = ['donald j. trump', 'cathy', 'tester']

# %%
candidates_for['label'] = candidates_for['label'].apply(lambda x: 'lib' if x.lower() in libs else x)
candidates_for['label'] = candidates_for['label'].apply(lambda x: 'con' if x.lower() in cons else x)

# %%
# the congress label people
candidates_for.loc[candidates_for['payers'] == 'schiff for congress', 'label'] = 'lib'
candidates_for.loc[candidates_for['payers'] == 'mccready for congress', 'label'] = 'lib'
candidates_for.loc[candidates_for['payers'] == 'o’connor for congress', 'label'] = 'con'

# %%
candidates_for.label.value_counts()
# Out:
# lib                                         48
# con                                          3
# everytown for gun safety action fund         2
# montanans                                    2
# national trust for historic preservation     1
# north dakota                                 1
# americans                                    1
# bennet for america                           1
# united states association                    1
# winning for women, inc.                      1
# better minnesota action fund                 1
# everytown for gun safety action fund inc     1
# america                                      1
# better place forests                         1
# concerned veterans for america               1
# tony                                         1
# victoria university of wellington            1
# center for biological diversity              1
# kentucky                                     1
# cal                                          1
# authorized                                   1
# texas                                        1
# reform austin                                1
# usa                                          1
# Name: label, dtype: int64

# %%
orgs = ['united states association', 'victoria university of wellington', 'center for biological diversity',
       'concerned veterans for america', 'concerned veterans for america', 'better minnesota action fund',
       'everytown for gun safety action fund inc', 'better place forests', 'winning for women, inc.', 
       'reform austin', 'national trust for historic preservation', 'everytown for gun safety action fund']

# %%
candidates_for['label'] = candidates_for['label'].apply(lambda x: 'org' if x in orgs else x)

# %%
candidates_for.label.value_counts()
candidates_for[(candidates_for['label'] != 'org') & (candidates_for['label'] != 'lib') & (candidates_for['label'] != 'con')]
# Out:
#                                                payers  \
# 76                                    amy for america
# 81                           americans for prosperity
# 90       and authorized by  andrew janz for congress.
# 97                                 bennet for america
# 105                                        cal for nc
# 162                               booker for kentucky
# 176                             montanans for bullock
# 177                              montanans for tester
# 191                            heidi for north dakota
# 219                                      mj for texas
# 228  tony for wisconsin. connie hutchison, treasurer.
# 233                                     usa for unhcr
#
#                                                               docs  \
# 76                                             (Amy, for, America)
# 81                                    (Americans, for, Prosperity)
# 90        (and, Authorized, by,  , Andrew, Janz, for, Congress, .)
# 97                                          (Bennet, for, America)
# 105                                                 (CAL, FOR, NC)
# 162                                        (BOOKER, FOR, KENTUCKY)
# 176                                      (Montanans, for, Bullock)
# 177                                       (Montanans, for, Tester)
# 191                                    (Heidi, for, North, Dakota)
# 219                                               (MJ, for, Texas)
# 228  (Tony, for, Wisconsin, ., Connie, Hutchison, ,, Treasurer, .)
# 233                                              (USA, for, UNHCR)
#
#                                      lemmatized_docs  \
# 76                                    [Amy, America]
# 81                           [Americans, prosperity]
# 90               [authorize, Andrew, Janz, Congress]
# 97                                 [Bennet, America]
# 105                                            [CAL]
# 162                               [BOOKER, KENTUCKY]
# 176                             [Montanans, Bullock]
# 177                              [Montanans, Tester]
# 191                           [Heidi, North, Dakota]
# 219                                          [Texas]
# 228  [Tony, Wisconsin, Connie, Hutchison, Treasurer]
# 233                                     [USA, UNHCR]
#
#                               named_ents              ne_labels  \
# 76                             [America]                  [GPE]
# 81                           [Americans]                 [NORP]
# 90   [Authorized, Andrew Janz, Congress]     [ORG, PERSON, ORG]
# 97                  [Bennet for America]                  [ORG]
# 105                            [CAL, NC]             [ORG, GPE]
# 162                           [KENTUCKY]                  [GPE]
# 176                          [Montanans]                 [NORP]
# 177                  [Montanans, Tester]            [NORP, GPE]
# 191                       [North Dakota]                  [GPE]
# 219                              [Texas]                  [GPE]
# 228  [Tony, Wisconsin, Connie Hutchison]  [PERSON, GPE, PERSON]
# 233                         [USA, UNHCR]             [GPE, ORG]
#
#                                              original               label
# 76                                    Amy for America             america
# 81                           Americans for Prosperity           americans
# 90       and Authorized by  Andrew Janz for Congress.          authorized
# 97                                 Bennet for America  bennet for america
# 105                                        CAL FOR NC                 cal
# 162                               BOOKER FOR KENTUCKY            kentucky
# 176                             Montanans for Bullock           montanans
# 177                              Montanans for Tester           montanans
# 191                            Heidi for North Dakota        north dakota
# 219                                      MJ for Texas               texas
# 228  Tony for Wisconsin. Connie Hutchison, Treasurer.                tony
# 233                                     USA for UNHCR                 usa

# %%
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*american.*$)', 'org', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*bennet.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*america.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*cal.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*kentucky.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*montanans.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*north dakota.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*texas.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*tony.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*usa.*$)', 'lib', regex=True)
candidates_for['label'] = candidates_for['label'].str.replace(r'(^.*authorized.*$)', 'lib', regex=True)

# %%
# concating the labeled candidates with the known_payers
candidates = list(candidates_for['payers'])
inverse_boolean_series = ~known_payers['payers'].isin(candidates)
known_payers = known_payers[inverse_boolean_series]
known_payers = pd.concat([known_payers, candidates_for], axis=0)
print(len(known_payers)) #
# Out:
# 187

# %%
# isolating the unlabeled payers in known payers
unlabeled_payers = known_payers[(known_payers['label'] != 'org') & (known_payers['label'] != 'lib') & (known_payers['label'] != 'con')]
display(unlabeled_payers)
# Out:
#                                            payers  \
# 66                                    bernie 2020
# 67                              hickenlooper 2020
# 68                                      cory 2020
# 69                                gillibrand 2020
# 70                                314 action fund
# ..                                            ...
# 240                        world food program usa
# 241                           world wildlife fund
# 242  yale program on climate change communication
# 249        the national network of abortion funds
# 252                the voter participation center
#
#                                                     docs  \
# 66                                        (BERNIE, 2020)
# 67                                  (Hickenlooper, 2020)
# 68                                          (Cory, 2020)
# 69                                    (Gillibrand, 2020)
# 70                                   (314, ACTION, FUND)
# ..                                                   ...
# 240                          (World, Food, Program, USA)
# 241                              (World, Wildlife, Fund)
# 242  (Yale, Program, on, Climate, Change, Communication)
# 249        (the, National, Network, of, Abortion, Funds)
# 252                  (the, Voter, Participation, Center)
#
#                                      lemmatized_docs  \
# 66                                          [BERNIE]
# 67                                    [Hickenlooper]
# 68                                            [Cory]
# 69                                      [Gillibrand]
# 70                                    [action, FUND]
# ..                                               ...
# 240                      [World, Food, Program, USA]
# 241                          [World, Wildlife, Fund]
# 242  [Yale, Program, Climate, Change, communication]
# 249             [National, Network, Abortion, Funds]
# 252                   [Voter, Participation, Center]
#
#                                    named_ents   ne_labels  \
# 66                                     [2020]      [DATE]
# 67                                     [2020]      [DATE]
# 68                                     [2020]      [DATE]
# 69                                     [2020]      [DATE]
# 70                                      [314]  [CARDINAL]
# ..                                        ...         ...
# 240                  [World Food Program USA]       [ORG]
# 241                     [World Wildlife Fund]       [ORG]
# 242                            [Yale Program]       [ORG]
# 249  [the National Network of Abortion Funds]       [ORG]
# 252          [the Voter Participation Center]       [ORG]
#
#                                          original  \
# 66                                    BERNIE 2020
# 67                              Hickenlooper 2020
# 68                                      Cory 2020
# 69                                Gillibrand 2020
# 70                                314 ACTION FUND
# ..                                            ...
# 240                        World Food Program USA
# 241                           World Wildlife Fund
# 242  Yale Program on Climate Change Communication
# 249        the National Network of Abortion Funds
# 252                the Voter Participation Center
#
#                                       label
# 66                                  missing
# 67                                  missing
# 68                                  missing
# 69                                  missing
# 70                                      314
# ..                                      ...
# 240                  world food program usa
# 241                     world wildlife fund
# 242                            yale program
# 249  the national network of abortion funds
# 252          the voter participation center
#
# [102 rows x 7 columns]

# %%
# from the view of the df, i can spot a few more liberal payers off the bat.
libs = ['andrew yang', 'biden', 'bernie 2020', 'mike bloomberg',
        'mike gravel', 'richard ojeda', 'tom steyer']
unlabeled_payers['label'] = unlabeled_payers['label'].apply(lambda x: 'lib' if x.lower() in libs else x)
display(unlabeled_payers)
# Out:
#                                            payers  \
# 66                                    bernie 2020
# 67                              hickenlooper 2020
# 68                                      cory 2020
# 69                                gillibrand 2020
# 70                                314 action fund
# ..                                            ...
# 240                        world food program usa
# 241                           world wildlife fund
# 242  yale program on climate change communication
# 249        the national network of abortion funds
# 252                the voter participation center
#
#                                                     docs  \
# 66                                        (BERNIE, 2020)
# 67                                  (Hickenlooper, 2020)
# 68                                          (Cory, 2020)
# 69                                    (Gillibrand, 2020)
# 70                                   (314, ACTION, FUND)
# ..                                                   ...
# 240                          (World, Food, Program, USA)
# 241                              (World, Wildlife, Fund)
# 242  (Yale, Program, on, Climate, Change, Communication)
# 249        (the, National, Network, of, Abortion, Funds)
# 252                  (the, Voter, Participation, Center)
#
#                                      lemmatized_docs  \
# 66                                          [BERNIE]
# 67                                    [Hickenlooper]
# 68                                            [Cory]
# 69                                      [Gillibrand]
# 70                                    [action, FUND]
# ..                                               ...
# 240                      [World, Food, Program, USA]
# 241                          [World, Wildlife, Fund]
# 242  [Yale, Program, Climate, Change, communication]
# 249             [National, Network, Abortion, Funds]
# 252                   [Voter, Participation, Center]
#
#                                    named_ents   ne_labels  \
# 66                                     [2020]      [DATE]
# 67                                     [2020]      [DATE]
# 68                                     [2020]      [DATE]
# 69                                     [2020]      [DATE]
# 70                                      [314]  [CARDINAL]
# ..                                        ...         ...
# 240                  [World Food Program USA]       [ORG]
# 241                     [World Wildlife Fund]       [ORG]
# 242                            [Yale Program]       [ORG]
# 249  [the National Network of Abortion Funds]       [ORG]
# 252          [the Voter Participation Center]       [ORG]
#
#                                          original  \
# 66                                    BERNIE 2020
# 67                              Hickenlooper 2020
# 68                                      Cory 2020
# 69                                Gillibrand 2020
# 70                                314 ACTION FUND
# ..                                            ...
# 240                        World Food Program USA
# 241                           World Wildlife Fund
# 242  Yale Program on Climate Change Communication
# 249        the National Network of Abortion Funds
# 252                the Voter Participation Center
#
#                                       label
# 66                                  missing
# 67                                  missing
# 68                                  missing
# 69                                  missing
# 70                                      314
# ..                                      ...
# 240                  world food program usa
# 241                     world wildlife fund
# 242                            yale program
# 249  the national network of abortion funds
# 252          the voter participation center
#
# [102 rows x 7 columns]

# %%
# i can also spot a few obvious libs and cons by the lem democrat, republic, progressive
unlabeled_payers['label'] = unlabeled_payers['label'].str.replace(r'(^.*emocrat.*$)', 'lib', regex=True)
unlabeled_payers['label'] = unlabeled_payers['label'].str.replace(r'(^.*epublican.*$)', 'con', regex=True)
unlabeled_payers['label'] = unlabeled_payers['label'].str.replace(r'(^.*rogressive.*$)', 'lib', regex=True)

# %%
# need to fix the 2020 vals
unlabeled_payers.loc[unlabeled_payers['payers'] == 'hickenlooper 2020', 'label'] = 'lib'
unlabeled_payers.loc[unlabeled_payers['payers'] == 'bernie 2020', 'label'] = 'lib'
unlabeled_payers.loc[unlabeled_payers['payers'] == 'cory 2020', 'label'] = 'lib'
unlabeled_payers.loc[unlabeled_payers['payers'] == 'gillibrand 2020', 'label'] = 'lib'
unlabeled_payers.loc[unlabeled_payers['payers'] == 'tulsi now', 'label'] = 'lib'

# %%
display(unlabeled_payers)
# Out:
#                                            payers  \
# 66                                    bernie 2020
# 67                              hickenlooper 2020
# 68                                      cory 2020
# 69                                gillibrand 2020
# 70                                314 action fund
# ..                                            ...
# 240                        world food program usa
# 241                           world wildlife fund
# 242  yale program on climate change communication
# 249        the national network of abortion funds
# 252                the voter participation center
#
#                                                     docs  \
# 66                                        (BERNIE, 2020)
# 67                                  (Hickenlooper, 2020)
# 68                                          (Cory, 2020)
# 69                                    (Gillibrand, 2020)
# 70                                   (314, ACTION, FUND)
# ..                                                   ...
# 240                          (World, Food, Program, USA)
# 241                              (World, Wildlife, Fund)
# 242  (Yale, Program, on, Climate, Change, Communication)
# 249        (the, National, Network, of, Abortion, Funds)
# 252                  (the, Voter, Participation, Center)
#
#                                      lemmatized_docs  \
# 66                                          [BERNIE]
# 67                                    [Hickenlooper]
# 68                                            [Cory]
# 69                                      [Gillibrand]
# 70                                    [action, FUND]
# ..                                               ...
# 240                      [World, Food, Program, USA]
# 241                          [World, Wildlife, Fund]
# 242  [Yale, Program, Climate, Change, communication]
# 249             [National, Network, Abortion, Funds]
# 252                   [Voter, Participation, Center]
#
#                                    named_ents   ne_labels  \
# 66                                     [2020]      [DATE]
# 67                                     [2020]      [DATE]
# 68                                     [2020]      [DATE]
# 69                                     [2020]      [DATE]
# 70                                      [314]  [CARDINAL]
# ..                                        ...         ...
# 240                  [World Food Program USA]       [ORG]
# 241                     [World Wildlife Fund]       [ORG]
# 242                            [Yale Program]       [ORG]
# 249  [the National Network of Abortion Funds]       [ORG]
# 252          [the Voter Participation Center]       [ORG]
#
#                                          original  \
# 66                                    BERNIE 2020
# 67                              Hickenlooper 2020
# 68                                      Cory 2020
# 69                                Gillibrand 2020
# 70                                314 ACTION FUND
# ..                                            ...
# 240                        World Food Program USA
# 241                           World Wildlife Fund
# 242  Yale Program on Climate Change Communication
# 249        the National Network of Abortion Funds
# 252                the Voter Participation Center
#
#                                       label
# 66                                      lib
# 67                                      lib
# 68                                      lib
# 69                                      lib
# 70                                      314
# ..                                      ...
# 240                  world food program usa
# 241                     world wildlife fund
# 242                            yale program
# 249  the national network of abortion funds
# 252          the voter participation center
#
# [102 rows x 7 columns]

# %%
# now, it's mostly orgs/pacs/etc leftover, so I'm going to try and identify those, then find a way to class them
orgs = list(unlabeled_payers[(unlabeled_payers['label'] != 'lib') & (unlabeled_payers['label'] != 'con')]['payers'])

# %%
orgs # we have to use the payer val in this case or we can't see the entire org name
# Out:
# ['314 action fund',
#  'aarp',
#  'the aclu',
#  'stand up america',
#  'define american',
#  'american civil liberties union',
#  'american medical association',
#  'amnesty international usa',
#  'anti-defamation league',
#  'ballotready',
#  'beachside media, inc.',
#  'bee site',
#  "ben & jerry's",
#  'bernie 2020.',
#  'doctors without borders/médecins sans frontières (msf)',
#  'credo mobile',
#  'crtv',
#  'care2',
#  'catholic relief services',
#  'chad benson',
#  'chesapeake bay foundation',
#  'civiqs',
#  'clean air clean energy washington 4347 roosevelt way ne seattle, wa 98105',
#  'our colorado way of life',
#  'cordray/sutton committee',
#  'covenant house international',
#  "dnc services corp./dem. nat'l committee",
#  'the dscc',
#  'dscc',
#  'daily wire',
#  "ditch fund and not authorized by any candidate or candidate's committee",
#  "emily's list",
#  'friends of the earth',
#  'exxonmobil',
#  'fctry',
#  'greenpeace, inc.',
#  'voters not politicians | po box 8362 grand rapids, mi 49518',
#  'greenpeace usa',
#  'hias',
#  'house majority pac, (202) 849-6052, and priorities usa action, (302) 469-3772. not authorized by any candidate or candidat…',
#  'union of concerned scientists, inc.',
#  'human rights campaign, inc.',
#  'ivn news',
#  "independence usa. not authorized by any candidate or candidate's committee.",
#  'international rescue committee',
#  'league of conservation voters',
#  "women's march",
#  'michigan leadership committee. not authorized by any candidate.',
#  'naral pro-choice america',
#  'national audubon society, inc.',
#  "the nrcc and not authorized by any candidate or candidate's committee.",
#  'nrdc',
#  'nrdc action fund',
#  'national audubon society',
#  'national domestic workers alliance',
#  'national education association',
#  'national geographic society',
#  'national park foundation',
#  'natural resources defense council',
#  'ozy media',
#  'ocean conservancy',
#  'oceana',
#  'ohio safe & healthy communities campaign',
#  'patagonia ',
#  'penzeys',
#  'planned parenthood federation of america',
#  "priorities usa action. 202-455-8428. not authorized by any candidate or candidate's committee.",
#  "priorities usa action and smp. (302) 469-3772. (202) 871-9255. not authorized by any candidate or candidate's committee.",
#  'sierra club',
#  'sandy hook promise',
#  'secure financial advisory group',
#  'southern poverty law center',
#  'solar energy today',
#  'tyt network',
#  'the beauty of life',
#  'the christian science monitor, an international news organization',
#  'the climate reality project',
#  'the humane society of the united states',
#  'the wall street journal',
#  'the washington post',
#  'the wilderness society',
#  'u.s. census bureau',
#  'u.s. chamber of commerce',
#  'unicef usa',
#  'union of concerned scientists',
#  'working families party',
#  'world food program usa',
#  'world wildlife fund',
#  'yale program on climate change communication',
#  'the national network of abortion funds',
#  'the voter participation center']

# %%
# let's knock out the ones where the label is the same as the payer val
unlabeled_payers['label'] = unlabeled_payers['label'].apply(lambda x: 'org' if x.lower() in orgs else x)

# %%
unlabeled_payers.label.value_counts()
# Out:
# org                                 64
# lib                                 11
# priorities usa action                2
# inc                                  2
# american                             1
# greenpeace                           1
# independence usa                     1
# aclu                                 1
# emily                                1
# house                                1
# america                              1
# bernie missing                       1
# colorado way of life                 1
# yale program                         1
# dnc services corp./dem               1
# grand rapids                         1
# today                                1
# the christian science monitor        1
# borders/médecins sans frontières     1
# ditch fund                           1
# march                                1
# nrcc                                 1
# clean air clean energy               1
# earth                                1
# 314                                  1
# patagonia                            1
# michigan leadership committee        1
# Name: label, dtype: int64

# %%
# adding the ones that didn't match
orgs += ['priorities usa action', 'inc', 'nrcc', 'the christian science monitor', 
         'yale program', 'march', '314', 'today', 'earth', 'ditch fund', 
         'clean air clean energy', 'independence usa', 'greenpeace', 'house', 
         'michigan leadership committee', 'emily', 'borders/médecins sans frontières',
         'patagonia', 'aclu', 'grand rapids', 'america', 'colorado way of life',
         'dnc services corp./dem', 'american', 'bernie missing']

unlabeled_payers['label'] = unlabeled_payers['label'].apply(lambda x: 'org' if x.lower() in orgs else x)
unlabeled_payers.label.value_counts()
# Out:
# org    91
# lib    11
# Name: label, dtype: int64

# %%
un_payers = list(unlabeled_payers['payers'])
inverse_boolean_series = ~known_payers['payers'].isin(un_payers)
known_payers = known_payers[inverse_boolean_series]
known_payers = pd.concat([known_payers, unlabeled_payers], axis=0) # concating the unlabeled_payers df back onto known_payers

# %%
known_payers['label'].value_counts()
# Out:
# org    104
# lib     78
# con      5
# Name: label, dtype: int64

# %%
import re

# %%
print(len(known_payers))
# Out:
# 187

# %%
# i'm going to skim through the entries and fix an obvious dupes
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*everytown.*$)', 'everytown for gun safety action fund', regex=True)
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*american civil liberties.*$)', 'aclu', regex=True)
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*aclu.*$)', 'aclu', regex=True)
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*greenpeace.*$)', 'greenpeace', regex=True)
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*nrdc.*$)', 'nrdc action func', regex=True)
known_payers['payers'] = known_payers['payers'].str.replace(r'(^.*priorities usa.*$)', 'priorities usa', regex=True)
# known_payers = known_payers.drop_duplicates(subset=['payers'])
print(len(known_payers)) # knocked out 7 duplicates
# Out:
# 187

# %%
known_payers.label.value_counts()
# Out:
# org    104
# lib     78
# con      5
# Name: label, dtype: int64

# %%
known_orgs = known_payers.loc[known_payers['label'] == 'org']

# %%
known_orgs['payers'] = known_orgs['payers'].str.replace('^ ', '', regex=True).replace(' $')
known_orgs['label'] = known_orgs['payers'].str.replace('^ ', '', regex=True).replace(' $')

# %%
libs = ['aclu', 'friends of the earth ', "dnc services corp./dem. nat'l committee", 'working families party', 'national trust for historic preservation', 'ballotready', 'chesapeake bay foundation ', 'league of conservation voters', 'unicef usa', 'national domestic workers alliance', 'world food program usa ', 'the washington post', 'bernie 2020.', 'care2', 'union of concerned scientists, inc.', 'southern poverty law center', 'planned parenthood federation of america', 'natural resources defense council ', 'union of concerned scientists', 'human rights campaign, inc.', 'catholic relief services', "independence usa. not authorized by any candidate or candidate's committee.", 'yale program on climate change communication', 'national park foundation', 'the dscc', 'everytown for gun safety action fund', '314 action fund', 'ocean conservancy', 'aarp', "ben & jerry's", 'covenant house international', "women's march", 'sierra club', 'the wilderness society', 'alliance for a better minnesota action fund', 'winning for women, inc.', 'credo mobile', 'tyt network ', 'the voter participation center', 'national geographic society', 'the national network of abortion funds', 'national education association', 'sandy hook promise', 'greenpeace', 'dscc', 'world wildlife fund', 'patagonia ', 'michigan leadership committee. not authorized by any candidate.', 'nrdc action func', 'priorities usa', 'national audubon society, inc. ', 'international rescue committee', 'center for biological diversity', 'penzeys', 'oceana', 'our colorado way of life', '314 action fund ', 'amnesty international usa', "emily's list", 'tyt network', 'the climate reality project', "ditch fund and not authorized by any candidate or candidate's committee", 'anti-defamation league', 'naral pro-choice america', 'clean air clean energy washington 4347 roosevelt way ne seattle, wa 98105', 'ohio safe & healthy communities campaign', 'reform austin, inc.', 'friends of the earth', 'chesapeake bay foundation', 'reform austin, inc. ']
cons = ["the nrcc and not authorized by any candidate or candidate's committee.", 'exxonmobil', 'chad benson ', 'reform austin, inc.', 'americans for prosperity', 'crtv', 'cordray/sutton committee', 'daily wire', 'concerned veterans for america']
drop = ['civiqs', 'stand up america ', 'better place forests', 'bee site', 'doctors without borders/médecins sans frontières (msf)', 'fctry', 'american medical association', 'united states association for unhcr', 'define american', 'predictit is a political prediction market, a stock market for politics. a project of victoria university of wellington, p…', 'beachside media, inc.', 'hias ', 'ivn news ', 'world food program usa', 'the wall street journal', 'solar energy today', 'national audubon society', 'chad benson', 'natural resources defense council', 'u.s. chamber of commerce', 'national audubon society, inc.', 'the beauty of life', 'ozy media', 'voters not politicians | po box 8362 grand rapids, mi 49518', 'the humane society of the united states', 'the christian science monitor, an international news organization', 'hias', 'stand up america', 'ivn news', 'u.s. census bureau', 'secure financial advisory group']

# %%
known_orgs['label'] = known_orgs['label'].apply(lambda x: 'lib' if x in libs else x)
known_orgs['label'] = known_orgs['label'].apply(lambda x: 'con' if x in cons else x)
known_orgs['label'] = known_orgs['label'].apply(lambda x: 'drop' if x in drop else x)

# %%
known_orgs.label.value_counts()
# Out:
# lib     69
# drop    28
# con      7
# Name: label, dtype: int64

# %%
inverse_boolean_series = ~known_orgs['label'].isin(drop)
known_orgs = known_orgs[inverse_boolean_series]

# %%
len(known_orgs)
# Out:
# 104

# %%
known_payers = pd.concat([known_orgs, known_payers], axis=0)

# %%
known_payers = known_payers[known_payers['label'] != 'org']
known_payers = known_payers[known_payers['label'] != 'drop']

# %%
known_payers.label.value_counts()
# Out:
# lib    147
# con     12
# Name: label, dtype: int64

# %%
known_payers
# Out:
#                                           payers  \
# 81                      americans for prosperity
# 101  alliance for a better minnesota action fund
# 112              center for biological diversity
# 118               concerned veterans for america
# 137         everytown for gun safety action fund
# ..                                           ...
# 173                      mike bloomberg 2020 inc
# 174                             mike gravel 2020
# 206             committee to elect richard ojeda
# 217                                    tulsi now
# 227                              tom steyer 2020
#
#                                                                                                                      docs  \
# 81                                                                                           (Americans, for, Prosperity)
# 101                                                                   (Alliance, for, a, Better, Minnesota, Action, Fund)
# 112                                                                                  (Center, for, Biological, Diversity)
# 118                                                                                   (Concerned, Veterans, for, America)
# 137  (Everytown, for, Gun, Safety, Action, Fund, ., Not, authorized, by, any, candidate, or, candidate, ’s, committee, .)
# ..                                                                                                                    ...
# 173                                                                                          (Mike, Bloomberg, 2020, Inc)
# 174                                                                                                  (Mike, Gravel, 2020)
# 206                                                                                (Committee, to, Elect, Richard, Ojeda)
# 217                                                                                                          (TULSI, NOW)
# 227                                                                                                   (Tom, Steyer, 2020)
#
#                                                                         lemmatized_docs  \
# 81                                                              [Americans, prosperity]
# 101                                         [alliance, Better, Minnesota, Action, Fund]
# 112                                                     [center, Biological, Diversity]
# 118                                                      [concerned, Veterans, America]
# 137  [Everytown, Gun, Safety, Action, Fund, authorize, candidate, candidate, committee]
# ..                                                                                  ...
# 173                                                              [Mike, Bloomberg, Inc]
# 174                                                                      [Mike, Gravel]
# 206                                                  [Committee, elect, Richard, Ojeda]
# 217                                                                             [TULSI]
# 227                                                                       [Tom, Steyer]
#
#                                  named_ents            ne_labels  \
# 81                              [Americans]               [NORP]
# 101          [Better Minnesota Action Fund]                [ORG]
# 112       [Center for Biological Diversity]                [ORG]
# 118        [Concerned Veterans for America]                [ORG]
# 137  [Everytown for Gun Safety Action Fund]                [ORG]
# ..                                      ...                  ...
# 173             [Mike Bloomberg, 2020, Inc]  [PERSON, DATE, GPE]
# 174                     [Mike Gravel, 2020]       [PERSON, DATE]
# 206                         [Richard Ojeda]             [PERSON]
# 217                             [TULSI NOW]                [ORG]
# 227                      [Tom Steyer, 2020]       [PERSON, DATE]
#
#                                                                                             original  \
# 81                                                                          Americans for Prosperity
# 101                                                      Alliance for a Better Minnesota Action Fund
# 112                                                                  Center for Biological Diversity
# 118                                                                   Concerned Veterans for America
# 137  Everytown for Gun Safety Action Fund. Not authorized by any candidate or candidate’s committee.
# ..                                                                                               ...
# 173                                                                          Mike Bloomberg 2020 Inc
# 174                                                                                 Mike Gravel 2020
# 206                                                                 Committee to Elect Richard Ojeda
# 217                                                                                        TULSI NOW
# 227                                                                                  Tom Steyer 2020
#
#     label
# 81    con
# 101   lib
# 112   lib
# 118   con
# 137   lib
# ..    ...
# 173   lib
# 174   lib
# 206   lib
# 217   lib
# 227   lib
#
# [159 rows x 7 columns]

# %% [markdown]
# ### unknown payers

# %%
# converting case to help remove dupes
unknown_payers_df = unknown_payers.sort_values(by='payers')
unknown_payers_df['payers'] = unknown_payers_df['payers'].apply(lambda x: x.lower())
# unknown_payers_df = unknown_payers_df.drop_duplicates(subset='payers')
print(len(unknown_payers_df))
# Out:
# 66

# %%
# since there are only 67 unknowns, i can visually scan the list to see if there are any other easy fixes
unknown_payers_df = unknown_payers_df.reset_index().drop('index', axis=1)
display(unknown_payers)
# Out:
#                                                                                     payers  \
# 0                                                                   the nature conservancy
# 1                                                                    human rights campaign
# 2                                                                            bird + stone
# 3                                                                          need to impeach
# 4                                                                                    kialo
# ..                                                                                     ...
# 61  moveon.org political action, not authorized by any candidate or candidate’s committee.
# 62                                                                       aids united, inc.
# 63                                                trump make america great again committee
# 64                                                                   reason to believe pac
# 65                                                                       pac to the future
#
#                                                                                                         docs  \
# 0                                                                                 (The, Nature, Conservancy)
# 1                                                                                  (Human, Rights, Campaign)
# 2                                                                                           (Bird, +, Stone)
# 3                                                                                        (Need, to, Impeach)
# 4                                                                                                    (Kialo)
# ..                                                                                                       ...
# 61  (MoveOn.org, Political, Action, ,, not, authorized, by, any, candidate, or, candidate, ’s, committee, .)
# 62                                                                                   (AIDS, United, ,, Inc.)
# 63                                                           (TRUMP, MAKE, AMERICA, GREAT, AGAIN, COMMITTEE)
# 64                                                                                (Reason, To, Believe, PAC)
# 65                                                                                    (PAC, TO, THE, FUTURE)
#
#                                                                 lemmatized_docs  \
# 0                                                         [Nature, Conservancy]
# 1                                                     [Human, Rights, Campaign]
# 2                                                                 [bird, Stone]
# 3                                                               [need, impeach]
# 4                                                                       [Kialo]
# ..                                                                          ...
# 61  [MoveOn.org, Political, Action, authorize, candidate, candidate, committee]
# 62                                                         [AIDS, United, Inc.]
# 63                                           [TRUMP, AMERICA, GREAT, COMMITTEE]
# 64                                                       [reason, believe, PAC]
# 65                                                                [PAC, future]
#
#    named_ents ne_labels  \
# 0          []        []
# 1          []        []
# 2          []        []
# 3          []        []
# 4          []        []
# ..        ...       ...
# 61         []        []
# 62         []        []
# 63         []        []
# 64         []        []
# 65         []        []
#
#                                                                                   original  \
# 0                                                                   The Nature Conservancy
# 1                                                                    Human Rights Campaign
# 2                                                                            Bird + Stone
# 3                                                                          Need to Impeach
# 4                                                                                    Kialo
# ..                                                                                     ...
# 61  MoveOn.org Political Action, not authorized by any candidate or candidate’s committee.
# 62                                                                       AIDS United, Inc.
# 63                                                TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE
# 64                                                                   Reason To Believe PAC
# 65                                                                       PAC TO THE FUTURE
#
#       label
# 0   missing
# 1   missing
# 2   missing
# 3   missing
# 4   missing
# ..      ...
# 61  missing
# 62  missing
# 63  missing
# 64  missing
# 65  missing
#
# [66 rows x 7 columns]

# %%
# i can see there are a few examples where it is obviously the same organization
# so I can write a few quick lines and fix those obvious dupes
unknown_payers_df['payers'] = unknown_payers_df['payers'].str.replace(r'(^.*moveon\.org.*$)', 'moveon.org', regex=True)
unknown_payers_df['payers'] = unknown_payers_df['payers'].str.replace(r'(^.*trump.*$)', 'maga committee', regex=True)
unknown_payers_df['payers'] = unknown_payers_df['payers'].str.replace(r'(^.*swing left.*$)', 'swing left', regex=True)
unknown_payers_df['payers'] = unknown_payers_df['payers'].str.replace(r'(^.*prager.*$)', 'prager u', regex=True)
unknown_payers_df['payers'] = unknown_payers_df['payers'].str.replace(r'(^.*planned parenthood.*$)', 'planned parenthood', regex=True)
# unknown_payers_df = unknown_payers_df.drop_duplicates(subset='payers')

print(len(unknown_payers_df)) # 58 -- knocked off 8 duplicates
display(unknown_payers_df)
# Out:
# 66
#                                                                       payers  \
# 0                                                          aids united, inc.
# 1                                                 alliance defending freedom
# 2                                                     america first policies
# 3                                                    ban assault weapons now
# 4   be a hero pac. not authorized by any candidate or candidate’s committee.
# ..                                                                       ...
# 61                                                    the nature conservancy
# 62                                                            maga committee
# 63                                                            maga committee
# 64                                                      votevets action fund
# 65                                                   wilderness society, the
#
#                                                                                            docs  \
# 0                                                                       (AIDS, United, ,, Inc.)
# 1                                                                (Alliance, Defending, Freedom)
# 2                                                                    (America, First, Policies)
# 3                                                                  (Ban, Assault, Weapons, NOW)
# 4   (Be, a, Hero, PAC, ., Not, authorized, by, any, candidate, or, candidate, ’s, committee, .)
# ..                                                                                          ...
# 61                                                                   (The, Nature, Conservancy)
# 62                                         (the, Trump, Make, America, Great, Again, Committee)
# 63                                              (TRUMP, MAKE, AMERICA, GREAT, AGAIN, COMMITTEE)
# 64                                                                     (VoteVets, Action, Fund)
# 65                                                                (WILDERNESS, SOCIETY, ,, THE)
#
#                                             lemmatized_docs named_ents  \
# 0                                      [AIDS, United, Inc.]         []
# 1                               [Alliance, defend, Freedom]         []
# 2                                       [America, Policies]         []
# 3                                   [Ban, Assault, Weapons]         []
# 4   [Hero, PAC, authorize, candidate, candidate, committee]         []
# ..                                                      ...        ...
# 61                                    [Nature, Conservancy]         []
# 62                       [Trump, America, Great, Committee]         []
# 63                       [TRUMP, AMERICA, GREAT, COMMITTEE]         []
# 64                                 [VoteVets, Action, Fund]         []
# 65                                    [WILDERNESS, SOCIETY]         []
#
#    ne_labels  \
# 0         []
# 1         []
# 2         []
# 3         []
# 4         []
# ..       ...
# 61        []
# 62        []
# 63        []
# 64        []
# 65        []
#
#                                                                     original  \
# 0                                                          AIDS United, Inc.
# 1                                                 Alliance Defending Freedom
# 2                                                     America First Policies
# 3                                                    Ban Assault Weapons NOW
# 4   Be a Hero PAC. Not authorized by any candidate or candidate’s committee.
# ..                                                                       ...
# 61                                                    The Nature Conservancy
# 62                              the Trump Make America Great Again Committee
# 63                                  TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE
# 64                                                      VoteVets Action Fund
# 65                                                   WILDERNESS SOCIETY, THE
#
#       label
# 0   missing
# 1   missing
# 2   missing
# 3   missing
# 4   missing
# ..      ...
# 61  missing
# 62  missing
# 63  missing
# 64  missing
# 65  missing
#
# [66 rows x 7 columns]

# %%
# next, I skimmed through the 58 entries, and classified the ones i knew as liberal or conservative. 
# for the ones I was unsure of, I checked sites like open secrets

cons = ['alliance defending freedom', 'america first policies', 'care', 'civic action', 'judicial watch', 
        'keep and bear', 'life outreach international ', 'prager u', 'the lincoln project', 'maga committee']
libs = ['ban assault weapons now', 'be a hero pac. not authorized by any candidate or candidate’s committee.',
       'bird + stone ', 'bullock for president', 'color of change', 'covenant house', 'dccc', 'ditch fund',
       'dissent pins', 'end citizens united', 'environmental defense fund', 'fair fight action', 'feeding america',
        'fwd.us', 'heifer international', 'hoover institution', 'human rights campaign', 'human rights watch',
       'indivisible action', 'indivisible project', 'julián for the future', 'justice democrats pac', 'moveon.org',
       'need to impeach', 'oxfam america', 'planned parenthood', 'progressive turnout project', 'reproaction',
       'pac to the future', 'reason to believe pac', 'shareblue media', 'swing left', 'the intercept', 'the nature conservancy',
       'votevets action fund', 'the motley fool', 'the nature conservancy', 'wilderness society, the',
       'bird + stone ', 'defenders of wildlife', 'defending democracy together', 'earthjustice', '314 action fund']

drop = ['mercy corps', 'phone2action', 'cleancult', 'aids united, inc.', 'no on proposition 8: stop the dangerous dialysis proposition', 'news for democracy', 'no kid hungry', 'kialo']

unknown_payers_df['label'] = unknown_payers_df['payers'].apply(lambda x: 'lib' if x.lower() in libs else x)
unknown_payers_df['label'] = unknown_payers_df['label'].apply(lambda x: 'con' if x.lower() in cons else x)
unknown_payers_df['label'] = unknown_payers_df['label'].apply(lambda x: 'drop' if x.lower() in drop else x)
unknown_payers_df.label.value_counts()
# Out:
# lib     46
# con     12
# drop     8
# Name: label, dtype: int64

# %%
# there are some leftover that I could not classify, that I will drop

# %%
boolean_series = unknown_payers_df['label'].isin(['lib', 'con'])
unknown_payers_df = unknown_payers_df[boolean_series]

# %%
len(unknown_payers_df)
# Out:
# 58

# %%
unknown_payers_df.label.value_counts()
# Out:
# lib    46
# con    12
# Name: label, dtype: int64

# %%
known_payers.label.value_counts()
# Out:
# lib    147
# con     12
# Name: label, dtype: int64

# %%
payer_data = pd.concat([unknown_payers_df, known_payers], axis=0)

# %%
payer_data.label.value_counts()
# Out:
# lib    193
# con     24
# Name: label, dtype: int64

# %%
payer_dict = dict(zip(payer_data['original'], payer_data['label']))

# %%
payer_dict
# Out:
# {'Alliance Defending Freedom': 'con',
#  'America First Policies': 'con',
#  'Ban Assault Weapons NOW': 'lib',
#  'Be a Hero PAC. Not authorized by any candidate or candidate’s committee.': 'lib',
#  'Bird + Stone ': 'lib',
#  'Bullock for President': 'lib',
#  'CARE': 'con',
#  'Civic Action': 'con',
#  'Color Of Change': 'lib',
#  'Covenant House': 'lib',
#  'DCCC': 'lib',
#  'Defenders of Wildlife': 'lib',
#  'Defending Democracy Together': 'lib',
#  'Dissent Pins': 'lib',
#  'DITCH FUND': 'lib',
#  'Earthjustice': 'lib',
#  'END CITIZENS UNITED': 'lib',
#  'Environmental Defense Fund': 'lib',
#  'Fair Fight Action': 'lib',
#  'Feeding America': 'lib',
#  'FWD.us': 'lib',
#  'Heifer International': 'lib',
#  'Hoover Institution': 'lib',
#  'Human Rights Campaign': 'lib',
#  'Human Rights Watch': 'lib',
#  'Indivisible Action': 'lib',
#  'Indivisible Project': 'lib',
#  'Judicial Watch': 'con',
#  'Julián for the Future': 'lib',
#  'JUSTICE DEMOCRATS PAC': 'lib',
#  'Keep and Bear': 'con',
#  'LIFE Outreach International ': 'con',
#  'MOVEON.ORG CIVIC ACTION': 'lib',
#  'MoveOn.org Civic Action.': 'lib',
#  'MOVEON.ORG POLITICAL ACTION': 'lib',
#  "MoveOn.org Political Action, not authorized by any candidate or candidate's committee.": 'lib',
#  'MoveOn.org Political Action, not authorized by any candidate or candidate’s committee.': 'lib',
#  "MoveOn.org Political Action, pol.moveon.org, not authorized by any candidate or candidate's committee.": 'lib',
#  'Need to Impeach': 'lib',
#  'Oxfam America': 'lib',
#  'PAC TO THE FUTURE': 'lib',
#  'Planned Parenthood Action Fund': 'lib',
#  'Planned Parenthood Action Fund.': 'lib',
#  'PragerU': 'con',
#  'PragerU ': 'con',
#  'Progressive Turnout Project': 'lib',
#  'Reason To Believe PAC': 'lib',
#  'Reproaction': 'lib',
#  'Shareblue Media': 'lib',
#  "Swing Left. Not authorized by any candidate or candidate's committee.": 'lib',
#  'The Intercept': 'lib',
#  'The Lincoln Project': 'con',
#  'The Motley Fool': 'lib',
#  'The Nature Conservancy': 'lib',
#  'the Trump Make America Great Again Committee': 'con',
#  'TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE': 'con',
#  'VoteVets Action Fund': 'lib',
#  'WILDERNESS SOCIETY, THE': 'lib',
#  'Americans for Prosperity': 'con',
#  'Alliance for a Better Minnesota Action Fund': 'lib',
#  'Center for Biological Diversity': 'lib',
#  'Concerned Veterans for America': 'con',
#  'Everytown for Gun Safety Action Fund. Not authorized by any candidate or candidate’s committee.': 'lib',
#  'Everytown for Gun Safety Action Fund': 'lib',
#  'Everytown for Gun Safety Action Fund Inc': 'lib',
#  'National Trust for Historic Preservation': 'lib',
#  'Reform Austin, Inc. ': 'lib',
#  'Winning For Women, Inc.': 'lib',
#  '314 ACTION FUND': 'lib',
#  'AARP': 'lib',
#  'the ACLU': 'lib',
#  'American Civil Liberties Union': 'lib',
#  'Amnesty International USA': 'lib',
#  'Anti-Defamation League': 'lib',
#  'BallotReady': 'lib',
#  "Ben & Jerry's": 'lib',
#  'Bernie 2020.': 'lib',
#  'CREDO Mobile': 'lib',
#  'CRTV': 'con',
#  'Care2': 'lib',
#  'Catholic Relief Services': 'lib',
#  'Chesapeake Bay Foundation': 'lib',
#  'Clean Air Clean Energy Washington 4347 Roosevelt Way NE Seattle, WA 98105': 'lib',
#  'Our Colorado Way of Life': 'lib',
#  'Cordray/Sutton Committee': 'con',
#  'Covenant House International': 'lib',
#  "DNC SERVICES CORP./DEM. NAT'L COMMITTEE": 'lib',
#  'the DSCC': 'lib',
#  'DSCC': 'lib',
#  'Daily Wire': 'con',
#  "Ditch Fund and not authorized by any candidate or candidate's committee": 'lib',
#  "EMILY's List": 'lib',
#  'Friends of the Earth': 'lib',
#  'ExxonMobil': 'con',
#  'GREENPEACE, INC.': 'lib',
#  'Greenpeace USA': 'lib',
#  'HOUSE MAJORITY PAC, (202) 849-6052, AND PRIORITIES USA ACTION, (302) 469-3772. NOT AUTHORIZED BY ANY CANDIDATE OR CANDIDAT…': 'lib',
#  'UNION OF CONCERNED SCIENTISTS, INC.': 'lib',
#  'HUMAN RIGHTS CAMPAIGN, INC.': 'lib',
#  "Independence USA. Not authorized by any candidate or candidate's committee.": 'lib',
#  'International Rescue Committee': 'lib',
#  'League of Conservation Voters': 'lib',
#  "Women's March": 'lib',
#  'Michigan Leadership Committee. Not authorized by any candidate.': 'lib',
#  'NARAL Pro-Choice America': 'lib',
#  "the NRCC and not authorized by any candidate or candidate's committee.": 'con',
#  'NRDC': 'lib',
#  'NRDC Action Fund': 'lib',
#  'National Domestic Workers Alliance': 'lib',
#  'National Education Association': 'lib',
#  'National Geographic Society': 'lib',
#  'National Park Foundation': 'lib',
#  'Ocean Conservancy': 'lib',
#  'Oceana': 'lib',
#  'Ohio Safe & Healthy Communities Campaign': 'lib',
#  'Patagonia ': 'lib',
#  'Penzeys': 'lib',
#  'Planned Parenthood Federation of America': 'lib',
#  "Priorities USA Action. 202-455-8428. Not authorized by any candidate or candidate's committee.": 'lib',
#  "Priorities USA Action and SMP. (302) 469-3772. (202) 871-9255. Not authorized by any candidate or candidate's committee.": 'lib',
#  'SIERRA CLUB': 'lib',
#  'Sandy Hook Promise': 'lib',
#  'Southern Poverty Law Center': 'lib',
#  'TYT Network': 'lib',
#  'The Climate Reality Project': 'lib',
#  'The Washington Post': 'lib',
#  'The Wilderness Society': 'lib',
#  'UNICEF USA': 'lib',
#  'Union of Concerned Scientists': 'lib',
#  'Working Families Party': 'lib',
#  'World Wildlife Fund': 'lib',
#  'Yale Program on Climate Change Communication': 'lib',
#  'the National Network of Abortion Funds': 'lib',
#  'the Voter Participation Center': 'lib',
#  'Democratic Governors Association': 'lib',
#  "Justice Democrats, not authorized by any candidate or candidate's committee.": 'lib',
#  'Stop Republicans': 'con',
#  'the Democratic Governors Association.': 'lib',
#  'the Democratic National Committee, 1.877.336.7200. Not authorized by any candidate or candidate’s committee.': 'lib',
#  'the Democratic National Committee': 'lib',
#  "the Florida Democratic Party. Not authorized by any candidate or candidate's committee.": 'lib',
#  'the National Democratic Training Committee': 'lib',
#  "the Progressive Change Campaign Committee PAC and not authorized by any candidate or candidate's committee. Contributions …": 'lib',
#  'the Republican National Committee': 'con',
#  'AMY MCGRATH FOR SENATE, INC.': 'lib',
#  'Adam Schiff for Congress': 'lib',
#  'Alexandria Ocasio-Cortez for Congress': 'lib',
#  'Amy for America': 'lib',
#  'Ammar Campa-Najjar for Congress.': 'lib',
#  'Amy McGrath for Senate': 'lib',
#  'Andrew Cuomo for Governor': 'lib',
#  'Andrew Gillum, Democrat, for Governor': 'lib',
#  'Andy Kim for Congress': 'lib',
#  'and Authorized by  Andrew Janz for Congress.': 'lib',
#  'BIDEN FOR PRESIDENT': 'lib',
#  'Bennet for America': 'lib',
#  'Beto for America': 'lib',
#  'Beto for Texas': 'lib',
#  'Bill Nelson for U.S. Senate': 'lib',
#  'CAL FOR NC': 'lib',
#  'SCHIFF FOR CONGRESS': 'lib',
#  'Cathy for Congress': 'con',
#  'O’Connor for Congress': 'con',
#  'McCready for Congress': 'lib',
#  'Cory Booker for Senate ': 'lib',
#  'DONALD J. TRUMP FOR PRESIDENT, INC.': 'con',
#  'DOUG JONES FOR SENATE COMMITTEE': 'lib',
#  'Dean Phillips for Congress': 'lib',
#  'Elizabeth for MA': 'lib',
#  'Giffords.': 'lib',
#  'Gillibrand for Senate': 'lib',
#  'HICKENLOOPER FOR COLORADO': 'lib',
#  'INSLEE FOR AMERICA': 'lib',
#  'JAIME HARRISON FOR US SENATE': 'lib',
#  'JB for Governor': 'lib',
#  'JON OSSOFF FOR SENATE': 'lib',
#  'Jaime Harrison for U.S. Senate': 'lib',
#  'Jeff Merkley for Oregon': 'lib',
#  'Joe Kennedy for Congress.': 'lib',
#  'BOOKER FOR KENTUCKY': 'lib',
#  'Kamala Harris For The People': 'lib',
#  'Kamala Harris for Senate': 'lib',
#  'Dr. Kim Schrier for Congress': 'lib',
#  'Lupe Valdez for Governor': 'lib',
#  'MARIANNE WILLIAMSON FOR PRESIDENT': 'lib',
#  'MARK KELLY FOR SENATE': 'lib',
#  'McCaskill for Missouri': 'lib',
#  'Mikie Sherrill for Congress': 'lib',
#  'Montanans for Bullock': 'lib',
#  'Montanans for Tester': 'lib',
#  'NANCY PELOSI FOR CONGRESS': 'lib',
#  'Heidi for North Dakota': 'lib',
#  'PETE FOR AMERICA, INC.': 'lib',
#  'Pete for America': 'lib',
#  'Randy Bryce for Congress': 'lib',
#  'SARA GIDEON FOR MAINE': 'lib',
#  'Seth Moulton for America': 'lib',
#  'Sharice for Congress': 'lib',
#  'Sinema for Arizona': 'lib',
#  'Stacey Abrams for Governor': 'lib',
#  'MJ for Texas': 'lib',
#  'Tony for Wisconsin. Connie Hutchison, Treasurer.': 'lib',
#  'USA for UNHCR': 'lib',
#  'WARREN FOR PRESIDENT, INC.': 'lib',
#  'Warren for President': 'lib',
#  'Zephyr for NY': 'lib',
#  'BERNIE 2020': 'lib',
#  'Hickenlooper 2020': 'lib',
#  'Cory 2020': 'lib',
#  'Gillibrand 2020': 'lib',
#  'Andrew Yang': 'lib',
#  'BIDEN VICTORY FUND': 'lib',
#  'Mike Bloomberg 2020 Inc': 'lib',
#  'Mike Gravel 2020': 'lib',
#  'Committee to Elect Richard Ojeda': 'lib',
#  'TULSI NOW': 'lib',
#  'Tom Steyer 2020': 'lib'}

# %%
fb_data['label'] = fb_data['paid_for_by'].map(payer_dict)

# %%
fb_data.label.value_counts()
# Out:
# lib    74485
# con     5309
# Name: label, dtype: int64

# %%
labeled_fb_data = fb_data.dropna(subset=['label'], axis=0)

# %%
len(labeled_fb_data)
# Out:
# 79794

# %%
lib = labeled_fb_data[labeled_fb_data['label'] =='lib']
con = labeled_fb_data[labeled_fb_data['label'] =='con']

# %%
lib_5k = lib.sample(5000)
con_5k = con.sample(5000)

# %%
lib_5k.to_csv('lib_5k_data.csv', index=False)
con_5k.to_csv('con_5k_data.csv', index=False)
