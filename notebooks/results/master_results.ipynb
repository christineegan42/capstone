# %%
import numpy as np
import pandas as pd
import os
from os import listdir
from datetime import datetime, date
from results import *

# %%
source_dir = "/Users/christineegan/flatiron-capstone/results/2021-04-22/"
results = calculate_mean_scores(source_dir)
save_results("master_results/", results)
# Out:
# master_results/2021-05-13/
# [*] Results saved to master_results/2021-05-13/11_25_00.csv
# 'master_results/2021-05-13/11_25_00.csv'

# %%
results
# Out:
#                  model  test size        f1  precision    recall  accuracy  \
# 0          Gaussian NB        0.2  9.652594   9.946706  9.376884  9.665000
# 1          Gaussian NB        0.3  9.566738   9.827016  9.321192  9.575000
# 2          Gaussian NB        0.4  9.475131   9.696291  9.265509  9.482500
# 3  Logistic Regression        0.2  6.421297   5.932202  7.020101  6.150000
# 4  Logistic Regression        0.3  6.397706   5.952960  6.937086  6.111667
# 5  Logistic Regression        0.4  6.334501   5.918794  6.836228  6.058750
# 6                  SVC        0.2  6.131266   6.123007  6.170854  6.182500
# 7                  SVC        0.3  6.040407   6.159647  5.980132  6.131667
# 8                  SVC        0.4  5.995838   6.118383  5.930521  6.091250
#
#     roc_auc  mean_score
# 0  9.663567    9.660950
# 1  9.576703    9.573330
# 2  9.484140    9.480714
# 3  6.154329    6.335586
# 4  6.106127    6.301109
# 5  6.052875    6.240230
# 6  6.182442    6.158014
# ...
